# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df= pd.read_csv("SeoulBikeData.csv",encoding= 'unicode_escape')

# %%
#Printing summary
df.head()
# Out:
#          Date  Rented Bike Count  Hour  Temperature(°C)  Humidity(%)  \
# 0  01/12/2017                254     0             -5.2           37
# 1  01/12/2017                204     1             -5.5           38
# 2  01/12/2017                173     2             -6.0           39
# 3  01/12/2017                107     3             -6.2           40
# 4  01/12/2017                 78     4             -6.0           36
#
#    Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# 0               2.2              2000                      -17.6
# 1               0.8              2000                      -17.6
# 2               1.0              2000                      -17.7
# 3               0.9              2000                      -17.6
# 4               2.3              2000                      -18.6
#
#    Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons     Holiday  \
# 0                      0.0           0.0            0.0  Winter  No Holiday
# ...

# %%
df.columns
# Out:
# Index(['Date', 'Rented Bike Count', 'Hour', 'Temperature(°C)', 'Humidity(%)',
#        'Wind speed (m/s)', 'Visibility (10m)', 'Dew point temperature(°C)',
#        'Solar Radiation (MJ/m2)', 'Rainfall(mm)', 'Snowfall (cm)', 'Seasons',
#        'Holiday', 'Functioning Day'],
#       dtype='object')

# %%
#Printing more info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Date                       8760 non-null   object
#  1   Rented Bike Count          8760 non-null   int64
#  2   Hour                       8760 non-null   int64
#  3   Temperature(°C)            8760 non-null   float64
#  4   Humidity(%)                8760 non-null   int64
#  5   Wind speed (m/s)           8760 non-null   float64
#  6   Visibility (10m)           8760 non-null   int64
#  7   Dew point temperature(°C)  8760 non-null   float64
#  8   Solar Radiation (MJ/m2)    8760 non-null   float64
#  9   Rainfall(mm)               8760 non-null   float64
#  10  Snowfall (cm)              8760 non-null   float64
#  11  Seasons                    8760 non-null   object
#  12  Holiday                    8760 non-null   object
# ...

# %%
#checking null values
df.isna().sum()
# Out:
# Date                         0
# Rented Bike Count            0
# Hour                         0
# Temperature(°C)              0
# Humidity(%)                  0
# Wind speed (m/s)             0
# Visibility (10m)             0
# Dew point temperature(°C)    0
# Solar Radiation (MJ/m2)      0
# Rainfall(mm)                 0
# Snowfall (cm)                0
# Seasons                      0
# Holiday                      0
# Functioning Day              0
# dtype: int64

# %%
#Printing Data types
df.dtypes
# Out:
# Date                          object
# Rented Bike Count              int64
# Hour                           int64
# Temperature(°C)              float64
# Humidity(%)                    int64
# Wind speed (m/s)             float64
# Visibility (10m)               int64
# Dew point temperature(°C)    float64
# Solar Radiation (MJ/m2)      float64
# Rainfall(mm)                 float64
# Snowfall (cm)                float64
# Seasons                       object
# Holiday                       object
# Functioning Day               object
# dtype: object

# %% [markdown]
# ## Performing EDA

# %%
#Describe Data
df.describe()
# Out:
#        Rented Bike Count         Hour  Temperature(°C)  Humidity(%)  \
# count        8760.000000  8760.000000      8760.000000  8760.000000
# mean          704.602055    11.500000        12.882922    58.226256
# std           644.997468     6.922582        11.944825    20.362413
# min             0.000000     0.000000       -17.800000     0.000000
# 25%           191.000000     5.750000         3.500000    42.000000
# 50%           504.500000    11.500000        13.700000    57.000000
# 75%          1065.250000    17.250000        22.500000    74.000000
# max          3556.000000    23.000000        39.400000    98.000000
#
#        Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# count       8760.000000       8760.000000                8760.000000
# mean           1.724909       1436.825799                   4.073813
# std            1.036300        608.298712                  13.060369
# min            0.000000         27.000000                 -30.600000
# ...

# %%
# renaming Rented bike count column
df.rename(columns={'Rented Bike Count':'Rented_bike_count'},inplace=True)

# %%
df.head()
# Out:
#          Date  Rented_bike_count  Hour  Temperature(°C)  Humidity(%)  \
# 0  01/12/2017                254     0             -5.2           37
# 1  01/12/2017                204     1             -5.5           38
# 2  01/12/2017                173     2             -6.0           39
# 3  01/12/2017                107     3             -6.2           40
# 4  01/12/2017                 78     4             -6.0           36
#
#    Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# 0               2.2              2000                      -17.6
# 1               0.8              2000                      -17.6
# 2               1.0              2000                      -17.7
# 3               0.9              2000                      -17.6
# 4               2.3              2000                      -18.6
#
#    Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons     Holiday  \
# 0                      0.0           0.0            0.0  Winter  No Holiday
# ...

# %%
#plot Hour vs Rented Bike Count
# plt.style.use("ggplot")
plt.rcParams['figure.figsize'] = 12, 8
sns.set()
sns.barplot('Hour',df['Rented_bike_count'], data=df);
plt.title('Hour vs Rented_bike_count');

# %%
df.Date=pd.to_datetime(df.Date)

# %%
df.head()
# Out:
#         Date  Rented_bike_count  Hour  Temperature(°C)  Humidity(%)  \
# 0 2017-01-12                254     0             -5.2           37
# 1 2017-01-12                204     1             -5.5           38
# 2 2017-01-12                173     2             -6.0           39
# 3 2017-01-12                107     3             -6.2           40
# 4 2017-01-12                 78     4             -6.0           36
#
#    Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# 0               2.2              2000                      -17.6
# 1               0.8              2000                      -17.6
# 2               1.0              2000                      -17.7
# 3               0.9              2000                      -17.6
# 4               2.3              2000                      -18.6
#
#    Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons     Holiday  \
# 0                      0.0           0.0            0.0  Winter  No Holiday
# ...

# %%
df.dtypes
# Out:
# Date                         datetime64[ns]
# Rented_bike_count                     int64
# Hour                                  int64
# Temperature(°C)                     float64
# Humidity(%)                           int64
# Wind speed (m/s)                    float64
# Visibility (10m)                      int64
# Dew point temperature(°C)           float64
# Solar Radiation (MJ/m2)             float64
# Rainfall(mm)                        float64
# Snowfall (cm)                       float64
# Seasons                              object
# Holiday                              object
# Functioning Day                      object
# dtype: object

# %%
df.Date.dt.year.unique()
# Out:
# array([2017, 2018], dtype=int64)

# %%
df.columns
# Out:
# Index(['Date', 'Rented_bike_count', 'Hour', 'Temperature(°C)', 'Humidity(%)',
#        'Wind speed (m/s)', 'Visibility (10m)', 'Dew point temperature(°C)',
#        'Solar Radiation (MJ/m2)', 'Rainfall(mm)', 'Snowfall (cm)', 'Seasons',
#        'Holiday', 'Functioning Day'],
#       dtype='object')

# %%
sns.boxplot(data=df[['Rented_bike_count', 'Hour', 'Temperature(°C)', 'Humidity(%)',
       'Wind speed (m/s)', 'Visibility (10m)', 'Dew point temperature(°C)',
       'Solar Radiation (MJ/m2)', 'Rainfall(mm)', 'Snowfall (cm)', 'Seasons',
       'Holiday', 'Functioning Day']]);

plt.xticks(rotation=45);

# %%
plt.rcParams['figure.figsize'] = 12, 10
df.hist(bins = 20);

# %%
sns.pointplot(df.Date.dt.month, df['Rented_bike_count'])
#sns.pointplot(df.Date.dt.dayofweek,df['Rented Bike Count'], color = 'r')

plt.xlabel('Month')
plt.ylabel('Rented Bike Count')
plt.title('Rented Bike Count vs Month')
# Out:
# Text(0.5, 1.0, 'Rented Bike Count vs Month')

# %%
# printing total number of unique seasons
df.Seasons.unique()
# Out:
# array(['Winter', 'Spring', 'Summer', 'Autumn'], dtype=object)

# %%
plt.rcParams['figure.figsize'] = 12, 8
sns.barplot(df.Seasons,df['Rented_bike_count'])
plt.title('Seasons vs Rented Bike Count')
# Out:
# Text(0.5, 1.0, 'Seasons vs Rented Bike Count')

# %%
df.head()
# Out:
#         Date  Rented_bike_count  Hour  Temperature(°C)  Humidity(%)  \
# 0 2017-01-12                254     0             -5.2           37
# 1 2017-01-12                204     1             -5.5           38
# 2 2017-01-12                173     2             -6.0           39
# 3 2017-01-12                107     3             -6.2           40
# 4 2017-01-12                 78     4             -6.0           36
#
#    Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# 0               2.2              2000                      -17.6
# 1               0.8              2000                      -17.6
# 2               1.0              2000                      -17.7
# 3               0.9              2000                      -17.6
# 4               2.3              2000                      -18.6
#
#    Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons     Holiday  \
# 0                      0.0           0.0            0.0  Winter  No Holiday
# ...

# %%
plt.rcParams['figure.figsize'] = 12, 8
#plt.bar(df.Holiday,df['Rented Bike Count'])
sns.set()
sns.countplot(df.Holiday);
plt.title('Holiday vs Rented Bike Count');

# %%
sns.barplot(df.Date.dt.dayofweek,df['Rented_bike_count']);
plt.xlabel('Day of week');
plt.title('Day of week vs Rented Bike Count');

# %% [markdown]
# ## Feature Engineering

# %%
df.head()
# Out:
#         Date  Rented_bike_count  Hour  Temperature(°C)  Humidity(%)  \
# 0 2017-01-12                254     0             -5.2           37
# 1 2017-01-12                204     1             -5.5           38
# 2 2017-01-12                173     2             -6.0           39
# 3 2017-01-12                107     3             -6.2           40
# 4 2017-01-12                 78     4             -6.0           36
#
#    Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# 0               2.2              2000                      -17.6
# 1               0.8              2000                      -17.6
# 2               1.0              2000                      -17.7
# 3               0.9              2000                      -17.6
# 4               2.3              2000                      -18.6
#
#    Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons     Holiday  \
# 0                      0.0           0.0            0.0  Winter  No Holiday
# ...

# %%
df.Rented_bike_count.hist(bins = 50);

# %% [markdown]
# # Analysing Rented Bike Count: plotting its mean and median lines

# %%
# creating histogram
sns.distplot(df.Rented_bike_count,bins=50)
plt.axvline(df.Rented_bike_count.mean(),linestyle='dashed',color='b')
plt.axvline(df.Rented_bike_count.median(),linestyle='dashed',color='red')

# %%
# applying square root reansformation to normalize the data
sns.distplot(np.sqrt(df.Rented_bike_count),bins=50)

plt.axvline(np.sqrt(df.Rented_bike_count).mean(),linestyle='dashed',color='b')
plt.axvline(np.sqrt(df.Rented_bike_count).median(),linestyle='dashed',color='red')

# %%
numeric_features = df.describe().columns
numeric_features
# Out:
# Index(['Rented_bike_count', 'Hour', 'Temperature(°C)', 'Humidity(%)',
#        'Wind speed (m/s)', 'Visibility (10m)', 'Dew point temperature(°C)',
#        'Solar Radiation (MJ/m2)', 'Rainfall(mm)', 'Snowfall (cm)'],
#       dtype='object')

# %%
#@title Default title text
# plot a bar plot for each numerical feature count (except car_ID)

for col in numeric_features[1:]:
    fig = plt.figure(figsize=(9, 6))
    ax = fig.gca()
    feature = df[col]
    feature.hist(bins=50, ax = ax)
    ax.axvline(feature.mean(), color='blue', linestyle='dashed' )
    ax.axvline(feature.median(), color='red', linestyle='dashed')    
    ax.set_title(col)
plt.show()

# %%
for col in numeric_features[1:-1]:
    fig = plt.figure(figsize=(9, 6))
    ax = fig.gca()
    feature = df[col]
    label = df['Rented_bike_count']
    correlation = feature.corr(label)
    plt.scatter(x=feature, y=label)
    plt.xlabel(col)
    plt.ylabel('Rented_bike_count')
    ax.set_title('Rented_bike_count vs ' + col + '- correlation: ' + str(correlation))
    z = np.polyfit(df[col], df['Rented_bike_count'], 1)
    y_hat = np.poly1d(z)(df[col])

    plt.plot(df[col], y_hat, "r--")

plt.show()

# %%
# plotting the correlation heatmap
plt.rcParams['figure.figsize']=(12,8)
sns.heatmap(abs(df.corr()),annot=True,cmap='coolwarm')

# %%
# checking Multicollinearity

from statsmodels.stats.outliers_influence import variance_inflation_factor
def calc_vif(X):

    # Calculating VIF
    vif = pd.DataFrame()
    vif["variables"] = X.columns
    vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

    return(vif)

# %%
# calculating VIF excluding dependent variable
calc_vif(df[[i for i in df.describe().columns if i not in ['Rented_bike_count']]])
# Out:
#                    variables        VIF
# 0                       Hour   4.418242
# 1            Temperature(°C)  33.385256
# 2                Humidity(%)   5.371996
# 3           Wind speed (m/s)   4.805364
# 4           Visibility (10m)   9.085977
# 5  Dew point temperature(°C)  17.126199
# 6    Solar Radiation (MJ/m2)   2.881590
# 7               Rainfall(mm)   1.081567
# 8              Snowfall (cm)   1.120833

# %%
calc_vif(df[[i for i in df.describe().columns if i not in ['Rented_bike_count','Dew point temperature(°C)']]])
# Out:
#                  variables       VIF
# 0                     Hour  3.921832
# 1          Temperature(°C)  3.228318
# 2              Humidity(%)  4.868221
# 3         Wind speed (m/s)  4.608625
# 4         Visibility (10m)  4.710170
# 5  Solar Radiation (MJ/m2)  2.246791
# 6             Rainfall(mm)  1.079158
# 7            Snowfall (cm)  1.120579

# %%
calc_vif(df[[i for i in df.describe().columns if i not in ['Rented_bike_count','Dew point temperature(°C)','Solar Radiation (MJ/m2)',]]])
# Out:
#           variables       VIF
# 0              Hour  3.920868
# 1   Temperature(°C)  2.469205
# 2       Humidity(%)  4.060509
# 3  Wind speed (m/s)  3.926260
# 4  Visibility (10m)  4.654167
# 5      Rainfall(mm)  1.078692
# 6     Snowfall (cm)  1.111248

# %%
calc_vif(df[[i for i in df.describe().columns if i not in ['Rented_bike_count','Dew point temperature(°C)',
                                                           'Solar Radiation (MJ/m2)','Humidity(%)']]])
# Out:
#           variables       VIF
# 0              Hour  3.823858
# 1   Temperature(°C)  2.113156
# 2  Wind speed (m/s)  3.852767
# 3  Visibility (10m)  4.180310
# 4      Rainfall(mm)  1.031393
# 5     Snowfall (cm)  1.051788

# %%
# defining numerical_features
numerical_features=[ 'Hour', 'Temperature(°C)', 'Wind speed (m/s)', 'Visibility (10m)', 'Rainfall(mm)', 'Snowfall (cm)']

# %%
# defining categorical_features
categorical_features=df.describe(include=['object','category']).columns

# %%
# removing date coluumn from categorical_features
categorical_features=set(categorical_features)-{'Date'}
categorical_features
# Out:
# {'Functioning Day', 'Holiday', 'Seasons'}

# %%
df.head()
# Out:
#         Date  Rented_bike_count  Hour  Temperature(°C)  Humidity(%)  \
# 0 2017-01-12                254     0             -5.2           37
# 1 2017-01-12                204     1             -5.5           38
# 2 2017-01-12                173     2             -6.0           39
# 3 2017-01-12                107     3             -6.2           40
# 4 2017-01-12                 78     4             -6.0           36
#
#    Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# 0               2.2              2000                      -17.6
# 1               0.8              2000                      -17.6
# 2               1.0              2000                      -17.7
# 3               0.9              2000                      -17.6
# 4               2.3              2000                      -18.6
#
#    Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons     Holiday  \
# 0                      0.0           0.0            0.0  Winter  No Holiday
# ...

# %%
# plotting categorical features
for col in categorical_features:
    counts = df[col].value_counts().sort_index()
    fig = plt.figure(figsize=(9, 6))
    ax = fig.gca()
    counts.plot.bar(ax = ax, color='steelblue')
    ax.set_title(col + ' counts')
    ax.set_xlabel(col) 
    ax.set_ylabel("Frequency")
plt.show()

# %%
# printing value_counts for holiday
df.Holiday.value_counts()
# Out:
# No Holiday    8328
# Holiday        432
# Name: Holiday, dtype: int64

# %%
# printing value_counts for functinal day

df['Functioning Day'].value_counts()
# Out:
# Yes    8465
# No      295
# Name: Functioning Day, dtype: int64

# %%
# plotting box plot Boxplot: Seasons vs Renal Bike Count
sns.set_style(style = 'darkgrid')
sns.boxplot(x=df.Seasons,y=df.Rented_bike_count)
plt.title('Boxplot: Seasons vs Renal Bike Count')
# Out:
# Text(0.5, 1.0, 'Boxplot: Seasons vs Renal Bike Count')

# %%
# aking a copy of original df
df1=df.copy()

# %%
# dropping the functioning day as there are very less values of one class compared to other
df1.drop('Functioning Day', axis = 1, inplace = True)

# %%
# performing label encoder to convert labels into numberical features
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder = LabelEncoder()

# %%
dummy = label_encoder.fit(df['Holiday'])
dummy = label_encoder.transform(df['Holiday'])
df1['Holiday'] = dummy
df1.drop('Holiday', axis = 1, inplace = True)

# %%
# performing label encoding in Seasons column
dummy = label_encoder.fit(df['Seasons'])
dummy = label_encoder.transform(df['Seasons'])
df1['Seasons'] = dummy
#df1.drop('Holiday', axis = 1, inplace = True)

# %%
df1.head()
# Out:
#         Date  Rented_bike_count  Hour  Temperature(°C)  Humidity(%)  \
# 0 2017-01-12                254     0             -5.2           37
# 1 2017-01-12                204     1             -5.5           38
# 2 2017-01-12                173     2             -6.0           39
# 3 2017-01-12                107     3             -6.2           40
# 4 2017-01-12                 78     4             -6.0           36
#
#    Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# 0               2.2              2000                      -17.6
# 1               0.8              2000                      -17.6
# 2               1.0              2000                      -17.7
# 3               0.9              2000                      -17.6
# 4               2.3              2000                      -18.6
#
#    Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm)  Seasons  Month  Day
# 0                      0.0           0.0            0.0        3      1   12
# ...

# %%
df.Holiday.value_counts()
# Out:
# No Holiday    8328
# Holiday        432
# Name: Holiday, dtype: int64

# %%
df.head()
# Out:
#         Date  Rented_bike_count  Hour  Temperature(°C)  Humidity(%)  \
# 0 2017-01-12                254     0             -5.2           37
# 1 2017-01-12                204     1             -5.5           38
# 2 2017-01-12                173     2             -6.0           39
# 3 2017-01-12                107     3             -6.2           40
# 4 2017-01-12                 78     4             -6.0           36
#
#    Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# 0               2.2              2000                      -17.6
# 1               0.8              2000                      -17.6
# 2               1.0              2000                      -17.7
# 3               0.9              2000                      -17.6
# 4               2.3              2000                      -18.6
#
#    Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons     Holiday  \
# 0                      0.0           0.0            0.0  Winter  No Holiday
# ...

# %%
sns.heatmap(abs(df1.corr()), annot = True, cmap = 'coolwarm');

# %%
calc_vif(df1[[i for i in df1.describe().columns if i not in ['Rented_bike_count', 'Date']]])
# Out:
#                     variables        VIF
# 0                        Hour   4.426814
# 1             Temperature(°C)  39.355679
# 2                 Humidity(%)  10.141826
# 3            Wind speed (m/s)   4.865093
# 4            Visibility (10m)   9.431917
# 5   Dew point temperature(°C)  21.270553
# 6     Solar Radiation (MJ/m2)   2.907133
# 7                Rainfall(mm)   1.083214
# 8               Snowfall (cm)   1.151762
# 9                     Seasons   3.290830
# 10                      Month   4.885622
# 11                        Day   4.350278

# %%
calc_vif(df1[[i for i in df1.describe().columns if i not in ['Rented Bike Count', 'Date', 'Dew point temperature(°C)',
                                                            'Humidity(%)', 'Solar Radiation (MJ/m2)']]])
# Out:
#            variables       VIF
# 0  Rented_bike_count  4.031051
# 1               Hour  4.761795
# 2    Temperature(°C)  3.203783
# 3   Wind speed (m/s)  4.084274
# 4   Visibility (10m)  5.923492
# 5       Rainfall(mm)  1.073083
# 6      Snowfall (cm)  1.128209
# 7            Seasons  2.756672
# 8              Month  3.896356
# 9                Day  3.530193

# %%
df1['Month'] = df1.Date.dt.month

# %%
df1['Day'] = df1.Date.dt.day

# %% [markdown]
# ## Machine Learning Model

# %%
numerical_features = set(df1.columns) - {'Rented_bike_count', 'Date', 'Dew point temperature(°C)',
                                                            'Humidity(%)', 'Solar Radiation (MJ/m2)'}

# %%
numerical_features = list(numerical_features)

# %%
# defining all numerical features 
numerical_features
# Out:
# ['Temperature(°C)',
#  'Wind speed (m/s)',
#  'Seasons',
#  'Hour',
#  'Snowfall (cm)',
#  'Month',
#  'Rainfall(mm)',
#  'Day',
#  'Visibility (10m)']

# %%
sns.heatmap(abs(df1[numerical_features].corr()), cmap = 'coolwarm', annot = True);

# %%
from sklearn.preprocessing import StandardScaler

# %%
X = df1[numerical_features].values

# %%
numerical_features
# Out:
# ['Temperature(°C)',
#  'Wind speed (m/s)',
#  'Seasons',
#  'Hour',
#  'Snowfall (cm)',
#  'Month',
#  'Rainfall(mm)',
#  'Day',
#  'Visibility (10m)']

# %%
from scipy.stats import zscore

# %%
X = df1[numerical_features].apply(zscore)

# %%
X
# Out:
#       Temperature(°C)  Wind speed (m/s)   Seasons      Hour  Snowfall (cm)  \
# 0           -1.513957          0.458476  1.349771 -1.661325      -0.171891
# 1           -1.539074         -0.892561  1.349771 -1.516862      -0.171891
# 2           -1.580936         -0.699556  1.349771 -1.372399      -0.171891
# 3           -1.597680         -0.796059  1.349771 -1.227936      -0.171891
# 4           -1.580936          0.554978  1.349771 -1.083473      -0.171891
# ...               ...               ...       ...       ...            ...
# 8755        -0.726961          0.844486 -1.342395  1.083473      -0.171891
# 8756        -0.793939          0.554978 -1.342395  1.227936      -0.171891
# 8757        -0.860918         -1.375075 -1.342395  1.372399      -0.171891
# 8758        -0.902779         -0.699556 -1.342395  1.516862      -0.171891
# 8759        -0.919524         -0.410048 -1.342395  1.661325      -0.171891
#
#          Month  Rainfall(mm)       Day  Visibility (10m)
# ...

# %%
y = np.sqrt(df1['Rented_bike_count'])

# %%
from sklearn.model_selection import train_test_split 
X_train, X_test, y_train, y_test = train_test_split( X,y , test_size = 0.2, random_state = 0) 
print(X_train.shape)
print(X_test.shape)
# Out:
# (7008, 9)
# (1752, 9)

# %%
type(y)
# Out:
# pandas.core.series.Series

# %% [markdown]
# # OLS Method

# %%
#statistical summary of dataset
import statsmodels.api as stats

a = stats.add_constant(X) 
model = stats.OLS(y, a).fit() 
prediction = model.predict(a)

# %%
# printing the model summary
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:      Rented_bike_count   R-squared:                       0.458
# Model:                            OLS   Adj. R-squared:                  0.457
# Method:                 Least Squares   F-statistic:                     821.2
# Date:                Fri, 18 Jun 2021   Prob (F-statistic):               0.00
# Time:                        15:05:58   Log-Likelihood:                -31838.
# No. Observations:                8760   AIC:                         6.370e+04
# Df Residuals:                    8750   BIC:                         6.377e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
# instantiating the linear regression model
linear = LinearRegression()

# %%
# fitting the model
linear.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# checking the score
linear.score(X_train, y_train)
# Out:
# 0.4648284498113856

# %%
# printing the coefficients
linear.coef_
# Out:
# array([ 5.87228994,  0.43798461, -0.92801265,  3.85817886, -0.33870327,
#         0.31348512, -2.04713732,  0.49678193,  1.52657703])

# %%
# printing the intercept
linear.intercept_
# Out:
# 23.562219328870654

# %%
# checking the test dataset values
y_pred = linear.predict(X_test)

# %%
# printing the priginal and predicted values
pd.DataFrame(zip(y_test, y_pred), columns = ['Original_Values', 'Predicted_values'])
# Out:
#       Original_Values  Predicted_values
# 0           17.888544         19.772685
# 1           24.083189         25.467195
# 2           15.033296         21.079937
# 3           12.845233         18.739482
# 4           25.416530         35.943403
# ...               ...               ...
# 1747         0.000000         18.176136
# 1748        23.388031         34.339197
# 1749        14.594520         17.849572
# 1750        36.482873         32.605702
# 1751        27.982137         19.275865
#
# [1752 rows x 2 columns]

# %% [markdown]
# ### Training Data Accuracy

# %%
#importing libraries for evaluation metrix
from sklearn.metrics import r2_score, mean_absolute_error
from sklearn.metrics import mean_squared_error

# %%
y_train_pred = linear.predict(X_train)

# %%
# printing Mean squared Error
MSE  = mean_squared_error(y_train**2, y_train_pred**2)
print("MSE :" , MSE)

# printingroot Mean squared Error
RMSE = np.sqrt(MSE)
print("RMSE :" ,RMSE)

MAE  = mean_absolute_error(y_train**2, y_train_pred**2)
print("MAE :" , MAE)

r2_train = r2_score(y_train**2, y_train_pred**2)
print('r2: ', r2_train)

# printing r2 csore
adjusted_r2 = 1-(1-r2_score((y_train**2), (y_train_pred**2)))*((X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1))
print("Adjusted R2 : ", adjusted_r2)
# Out:
# MSE : 221132.12887183757
# RMSE : 470.24688076779154
# MAE : 323.7188144020906
# r2:  0.46746334585028937
# Adjusted R2 :  0.46471200837190396

# %%
# printing Mean squared Error
MSE  = mean_squared_error(y_test**2, y_pred**2)
print("MSE :" , MSE)

# printingroot Mean squared Error
RMSE = np.sqrt(MSE)
print("RMSE :" ,RMSE)
# Out:
# MSE : 230919.37609557997
# RMSE : 480.54071221445946

# %%
# printing r2 csore
r2 = r2_score(y_test**2, y_pred**2)
print("R2 :" ,r2)

# printing r2 csore
adjusted_r2 = 1-(1-r2_score((y_test**2), (y_pred**2)))*((X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1))
print("Adjusted R2 : ", adjusted_r2)
# Out:
# R2 : 0.4482511040840418
# Adjusted R2 :  0.4454005070328113

# %%
#plotting the actual and predicted values
plt.plot(y_pred**2)
plt.plot(np.array(y_test**2))
plt.legend(["Predicted","Actual"])
plt.show()

# %%
sns.set()
#scatterplot of linear regression
plt.scatter(y_test**2, y_pred**2)
plt.xlabel('Actual')
plt.ylabel('Predicted')
# Out:
# Text(0, 0.5, 'Predicted')

# %% [markdown]
# # Lasso Regression

# %%
#fit lasso regression
from sklearn.linear_model import Lasso
lasso = Lasso(alpha=0.001) # set hyper parameter=0.01
lasso.fit(X_train, y_train)
# Out:
# Lasso(alpha=0.001)

# %%
y_pred=lasso.predict(X_test)

# %%
r2_score(y_test**2, y_pred**2)
# Out:
# 0.44822376811852127

# %%
# printing mean square error
MSE  = mean_squared_error(y_test**2, y_pred**2)
print("MSE :" , MSE)

# printing root mean square error
RMSE = np.sqrt(MSE)
print("RMSE :" ,RMSE)

## printing mean absolute square error
MAE  = mean_absolute_error(y_test**2, y_pred**2)
print("MAE :" , MAE)

# printing r square
r2 = r2_score(y_test**2, y_pred**2)
print("R2 :" ,r2)

# printing adjusted_r2
adjusted_r2 = 1-(1-r2_score((y_test**2),(y_pred**2)))*((X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1))
print("Adjusted R2 : ", adjusted_r2)
# Out:
# MSE : 230930.81681462747
# RMSE : 480.5526160730243
# MAE : 330.49782561882216
# R2 : 0.44822376811852127
# Adjusted R2 :  0.4453730298366997

# %% [markdown]
# # Ridge Regression

# %%
from sklearn.linear_model import Ridge

ridge  = Ridge(alpha=0.1)

# %%
ridge.fit(X_train,y_train)
# Out:
# Ridge(alpha=0.1)

# %%
ridge.score(X_train, y_train)
# Out:
# 0.464828449743129

# %%
# printing mean square error
MSE  = mean_squared_error(y_test**2, y_pred**2)
print("MSE :" , MSE)

# printing root mean square error
RMSE = np.sqrt(MSE)
print("RMSE :" ,RMSE)

## printing mean absolute square error
MAE  = mean_absolute_error(y_test**2, y_pred**2)
print("MAE :" , MAE)

# printing r square
r2 = r2_score(y_test**2, y_pred**2)
print("R2 :" ,r2)

# printing adjusted_r2
adjusted_r2 = 1-(1-r2_score((y_test**2),(y_pred**2)))*((X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1))
print("Adjusted R2 : ", adjusted_r2)
# Out:
# MSE : 230930.81681462747
# RMSE : 480.5526160730243
# MAE : 330.49782561882216
# R2 : 0.44822376811852127
# Adjusted R2 :  0.4453730298366997

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
#  create regressor object 
random_forest = RandomForestRegressor(n_estimators = 100, random_state = 0)

# %%
# fit the regressor with x and y data 
random_forest.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=0)

# %%
#predicted value
y_pred = random_forest.predict(X_test)

# %%
#MAE MSE RMSE and R2 values
MAE  = mean_absolute_error(y_test**2,y_pred**2)
MSE  = mean_squared_error(y_test**2, y_pred**2)
print("MAE :" , MAE)
print("MSE :" , MSE)

RMSE = np.sqrt(MSE)
print("RMSE :" ,RMSE)

r2 = r2_score(y_test**2, y_pred**2)
print("R2 :" ,r2)

#Adjusted R2 value
adjusted_r2 = 1-(1-r2_score((y_test**2), (y_pred**2)))*((X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1))
print("Adjusted R2 : ", adjusted_r2)
# Out:
# MAE : 180.14206290503958
# MSE : 88292.99153854197
# RMSE : 297.14136625273494
# R2 : 0.7896343139284046
# Adjusted R2 :  0.7885474648040393

# %%
features = X_train.columns
importances = random_forest.feature_importances_
indices = np.argsort(importances)

# %%
plt.title('Feature Importance')
plt.barh(range(len(indices)), importances[indices], align='center')
plt.yticks(range(len(indices)), [features[i] for i in indices])
plt.xlabel('Relative Importance')
# Out:
# Text(0.5, 0, 'Relative Importance')

# %% [markdown]
# # adaboost

# %%
# evaluate adaboost ensemble for regression
from numpy import mean
from numpy import std
#from sklearn.datasets import make_regression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.ensemble import AdaBoostRegressor
# define dataset
#X, y = make_regression(n_samples=1000, n_features=20, n_informative=15, noise=0.1, random_state=6)
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.20, random_state=48)
# define the model
model = AdaBoostRegressor()

# %%
model.fit(X_train,y_train)
# Out:
# AdaBoostRegressor()

# %%
y_pred=model.predict(X_test)

# %%
# evaluate the model
cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
n_scores = cross_val_score(model, X_train, y_train, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1, error_score='raise')
# report performance
print('MAE: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))

MSE  = mean_squared_error((y_test*2),(y_pred*2))
print("MSE :" , MSE)

RMSE = np.sqrt(MSE)
print("RMSE :" ,RMSE)

r2 = r2_score((y_test**2), (y_pred**2))
print("R2 :" ,r2)


adjusted_r2 = 1-(1-r2_score((y_test**2), (y_pred**2)))*((X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1))
print("Adjusted R2 : ", adjusted_r2)
# Out:
# MAE: -6.840 (0.260)
# MSE : 331.3564598636751
# RMSE : 18.203199165632263
# R2 : 0.42728265467584636
# Adjusted R2 :  0.42432372464833923

# %% [markdown]
# # xg boost

# %%
#importing XGboost and fitting XGboost
import xgboost as xgb

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.20, random_state=48)
dreg= xgb.XGBRegressor(
                        booster= 'gbtree',
                        colsample_bylevel= 1,
                        colsample_bynode= 1,
                        colsample_bytree= 0.7,
                        eta= 0.004,
                        gamma= 0,
                        importance_type= 'gain',
                        learning_rate= 0.2,
                        max_delta_step= 0,
                        max_depth= 10,
                        min_child_weight= 10,
                        n_estimators= 100,
                        n_jobs= -1,
                        objective= 'reg:linear',
                        random_state= 0,
                        reg_alpha= 0,
                        #reg_lambda= 1,
                        scale_pos_weight= 1,
                        subsample= 1,
                        verbosity= 2)
dreg.fit(X_train, y_train)
y_pred = dreg.predict(X_test)
#Find R-squared value
r2 = r2_score(y_test**2, y_pred**2)
# Find Adjusted R-squared value
adj_r2=1-(1-r2_score(y_test**2, y_pred**2))*((X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1))
train_score = dreg.score(X_train, y_train)
test_score = dreg.score(X_test,y_test)
print(f'Train score: {train_score}')
print(f'Test score: {test_score}')
# Out:
# [15:13:26] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# [15:13:26] INFO: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/tree/updater_prune.cc:101: tree pruning end, 160 extra nodes, 0 pruned nodes, max_depth=10
# [15:13:26] INFO: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/tree/updater_prune.cc:101: tree pruning end, 264 extra nodes, 0 pruned nodes, max_depth=10
# [15:13:26] INFO: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/tree/updater_prune.cc:101: tree pruning end, 336 extra nodes, 0 pruned nodes, max_depth=10
# [15:13:26] INFO: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/tree/updater_prune.cc:101: tree pruning end, 358 extra nodes, 0 pruned nodes, max_depth=10
# ...

# %%
r2
# Out:
# 0.8480554240823915

# %%
#MSE RMSE MAE values
MSE  = mean_squared_error(y_test**2, y_pred**2)
print("MSE :" , MSE)

RMSE = np.sqrt(MSE)
print("RMSE :" ,RMSE)

MAE  = mean_absolute_error(y_test**2, y_pred**2)
print("MAE :" , MAE)
# Out:
# MSE : 63772.95369005616
# RMSE : 252.53307444779617
# MAE : 155.33486750018633

# %%
#Adjusted R2
adj_r2
# Out:
# 0.8472704061815544

# %%
plt.plot(y_pred**2)
plt.plot(np.array(y_test**2))
plt.legend(["Predicted","Actual"])
plt.show()

# %%
plt.scatter(y_test**2, y_pred**2)
plt.xlabel('Actual')
plt.ylabel('Predicted')
# Out:
# Text(0, 0.5, 'Predicted')

# %%
feature_importance = dreg.get_booster().get_score(importance_type="gain")
list(feature_importance)
# Out:
# ['Seasons',
#  'Hour',
#  'Rainfall(mm)',
#  'Day',
#  'Wind speed (m/s)',
#  'Snowfall (cm)',
#  'Temperature(°C)',
#  'Month',
#  'Visibility (10m)']

# %%
feature_important = dreg.get_booster().get_score(importance_type="weight")
keys = list(feature_important.keys())
values = list(feature_important.values())

data = pd.DataFrame(data=values, index=keys, columns=["score"]).sort_values(by = "score", ascending=False)
data.plot(kind='bar')

# %% [markdown]
# # Cross Validation on xgboost

# %%
import warnings
from sklearn.model_selection import GridSearchCV
warnings.filterwarnings('ignore')
import xgboost as xgb

xgb = xgb.XGBRegressor(random_state=0)

# %%
#setting parameters
params = {"min_child_weight":[10,20], 
         'max_depth': [6, 8]}

# %%
#fitting the data
reg_gs = GridSearchCV(xgb,param_grid=params, verbose=1, cv=2)
reg_gs.fit(X, y)
# Out:
# Fitting 2 folds for each of 4 candidates, totalling 8 fits
# [15:20:53] INFO: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/tree/updater_prune.cc:101: tree pruning end, 66 extra nodes, 0 pruned nodes, max_depth=6
# [15:20:53] INFO: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/tree/updater_prune.cc:101: tree pruning end, 84 extra nodes, 0 pruned nodes, max_depth=6
# [15:20:53] INFO: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/tree/updater_prune.cc:101: tree pruning end, 86 extra nodes, 0 pruned nodes, max_depth=6
# [15:20:53] INFO: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/tree/updater_prune.cc:101: tree pruning end, 88 extra nodes, 0 pruned nodes, max_depth=6
# [15:20:53] INFO: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/tree/updater_prune.cc:101: tree pruning end, 88 extra nodes, 0 pruned nodes, max_depth=6
# ...

# %%
reg_gs.best_estimator_
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.300000012, max_delta_step=0, max_depth=8,
#              min_child_weight=20, missing=nan, monotone_constraints='()',
#              n_estimators=100, n_jobs=4, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %%
#assigning best estimators to variable
reg_optimal_model =reg_gs.best_estimator_
reg_optimal_model
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.300000012, max_delta_step=0, max_depth=8,
#              min_child_weight=20, missing=nan, monotone_constraints='()',
#              n_estimators=100, n_jobs=4, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %%
#train and test predicted values
train_preds = reg_optimal_model.predict(X_train)
test_preds = reg_optimal_model.predict(X_test)

# %%
y_pred = dreg.predict(X_test)

# %%
#optimal model score of test data
reg_optimal_model.score(X_test,y_test)
# Out:
# 0.9645695477158825

# %%
# R-squared value
r2 = r2_score(y_test**2, test_preds**2)
# Adjusted R-squared value
adj_r2=1-(1-r2_score(y_test**2, test_preds**2))*((X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1))

# %%
r2
# Out:
# 0.9592772150954361

# %%
adj_r2
# Out:
# 0.9590668218324389

# %%
#MSE RMSE MAE values
MSE  = mean_squared_error(y_test**2, y_pred**2)
print("MSE :" , MSE)

RMSE = np.sqrt(MSE)
print("RMSE :" ,RMSE)

MAE  = mean_absolute_error(y_test**2, y_pred**2)
print("MAE :" , MAE)
# Out:
# MSE : 63772.95369005616
# RMSE : 252.53307444779617
# MAE : 155.33486750018633

# %%
feature_important = dreg.get_booster().get_score(importance_type="weight")
keys = list(feature_important.keys())
values = list(feature_important.values())

data = pd.DataFrame(data=values, index=keys, columns=["score"]).sort_values(by = "score", ascending=False)
data.plot(kind='bar');

# %%
plt.plot(y_pred**2)
plt.plot(np.array(y_test**2))
plt.legend(["Predicted","Actual"])
plt.show()
